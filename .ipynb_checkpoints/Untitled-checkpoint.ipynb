# %%
import pandas as pd
fruits = pd.DataFrame([[30,21]], columns=['Apples','Bananas'])

# %%
fruits
# Out:
#    Apples  Bananas
# 0      30       21

# %%
Fruits = pd.DataFrame( [[35,21],[41,34]] , columns=['Apples','Bananas'], index=['2017 Sales','2018 Sales'])
Fruits
# Out:
#             Apples  Bananas
# 2017 Sales      35       21
# 2018 Sales      41       34

# %%
quantities = ['4 cups', '1 cup', '2 large', '1 can']
varities = ['Flour','Milk','Eggs','Spam']
Display_Items = pd.Series(quantities,index=varities, name='Dinner')
Display_Items
# Out:
# Flour     4 cups
# Milk       1 cup
# Eggs     2 large
# Spam       1 can
# Name: Dinner, dtype: object

# %%
file_path='~/PycharmProjects/PandasExplore/winemag-data-130k-v2.csv'
read_file = pd.read_csv(file_path,index_col=0)
wineMag = pd.DataFrame(read_file)
wineMag
# Out:
#        country  ...                   winery
# 0           US  ...                    Heitz
# 1        Spain  ...  Bodega Carmen Rodríguez
# ```        NaN  ...                      NaN
# 150928  France  ...                   Gosset
# 150929   Italy  ...            Alois Lageder
#
# [5 rows x 10 columns]

# %%
wineMag['country'][0]
# Out:
# 'US'

# %%
wineMag.country
# Out:
# 0             US
# 1          Spain
# ```          NaN
# 150928    France
# 150929     Italy
# Name: country, dtype: object

# %%
wineMag.iloc[0]
# Out:
# country                                             US
# description    This tremendous 100% varietal wine[...]
# designation                          Martha's Vineyard
# points                                            96.0
# price                                            235.0
# province                                    California
# region_1                                   Napa Valley
# region_2                                          Napa
# variety                             Cabernet Sauvignon
# winery                                           Heitz
# Name: 0, dtype: object

# %%
wineMag.iloc[:,0]
# Out:
# 0             US
# 1          Spain
# ```          NaN
# 150928    France
# 150929     Italy
# Name: country, dtype: object

# %%
wineMag.iloc[:3,0]
# Out:
# 0         US
# 1      Spain
# ```      NaN
# Name: country, dtype: object

# %%
wineMag.iloc[1:3,0]
# Out:
# 1      Spain
# ```      NaN
# Name: country, dtype: object

# %%
wineMag.iloc[[1,2,3],0]
# Out:
# 1          Spain
# ```          NaN
# 150928    France
# Name: country, dtype: object

# %%
wineMag.iloc[-5:]
# Out:
#        country  ...                   winery
# 0           US  ...                    Heitz
# 1        Spain  ...  Bodega Carmen Rodríguez
# ```        NaN  ...                      NaN
# 150928  France  ...                   Gosset
# 150929   Italy  ...            Alois Lageder
#
# [5 rows x 10 columns]

# %%
wineMag.iloc[0,'country']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py:769, in _LocationIndexer._validate_tuple_indexer(self, key)
#     768 try:
# --> 769     self._validate_key(k, i)
#     770 except ValueError as err:
#
# File /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py:1378, in _iLocIndexer._validate_key(self, key, axis)
#    1377 else:
# -> 1378     raise ValueError(f"Can only index by location with a [{self._valid_types}]")
#
# ValueError: Can only index by location with a [integer, integer slice (START point is INCLUDED, END point is EXCLUDED), listlike of integers, boolean array]
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Input In [40], in <cell line: 1>()
# ----> 1 wineMag.iloc[0,'country']
#
# File /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py:961, in _LocationIndexer.__getitem__(self, key)
#     959     if self._is_scalar_access(key):
#     960         return self.obj._get_value(*key, takeable=self._takeable)
# --> 961     return self._getitem_tuple(key)
#     962 else:
#     963     # we by definition only have the 0th axis
#     964     axis = self.axis or 0
#
# File /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py:1458, in _iLocIndexer._getitem_tuple(self, tup)
#    1456 def _getitem_tuple(self, tup: tuple):
# -> 1458     tup = self._validate_tuple_indexer(tup)
#    1459     with suppress(IndexingError):
#    1460         return self._getitem_lowerdim(tup)
#
# File /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py:771, in _LocationIndexer._validate_tuple_indexer(self, key)
#     769         self._validate_key(k, i)
#     770     except ValueError as err:
# --> 771         raise ValueError(
#     772             "Location based indexing can only have "
#     773             f"[{self._valid_types}] types"
#     774         ) from err
#     775 return key
#
# ValueError: Location based indexing can only have [integer, integer slice (START point is INCLUDED, END point is EXCLUDED), listlike of integers, boolean array] types

# %%
wineMagre.loc[:,['taster_name','taster_twitter_handle','points']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [41], in <cell line: 1>()
# ----> 1 wineMag.loc[:,['taster_name','taster_twitter_handle','points']]
#
# File /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py:961, in _LocationIndexer.__getitem__(self, key)
#     959     if self._is_scalar_access(key):
#     960         return self.obj._get_value(*key, takeable=self._takeable)
# --> 961     return self._getitem_tuple(key)
#     962 else:
#     963     # we by definition only have the 0th axis
#     964     axis = self.axis or 0
#
# File /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py:1149, in _LocIndexer._getitem_tuple(self, tup)
#    1146 if self._multi_take_opportunity(tup):
#    1147     return self._multi_take(tup)
# -> 1149 return self._getitem_tuple_same_dim(tup)
#
# File /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py:827, in _LocationIndexer._getitem_tuple_same_dim(self, tup)
#     824 if com.is_null_slice(key):
#     825     continue
# --> 827 retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#     828 # We should never have retval.ndim < self.ndim, as that should
#     829 #  be handled by the _getitem_lowerdim call above.
#     830 assert retval.ndim == self.ndim
#
# File /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py:1191, in _LocIndexer._getitem_axis(self, key, axis)
#    1188     if hasattr(key, "ndim") and key.ndim > 1:
#    1189         raise ValueError("Cannot index with multidimensional key")
# -> 1191     return self._getitem_iterable(key, axis=axis)
#    1193 # nested tuple slicing
#    1194 if is_nested_tuple(key, labels):
#
# File /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py:1132, in _LocIndexer._getitem_iterable(self, key, axis)
#    1129 self._validate_key(key, axis)
#    1131 # A collection of keys
# -> 1132 keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1133 return self.obj._reindex_with_indexers(
#    1134     {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#    1135 )
#
# File /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py:1327, in _LocIndexer._get_listlike_indexer(self, key, axis)
#    1324 ax = self.obj._get_axis(axis)
#    1325 axis_name = self.obj._get_axis_name(axis)
# -> 1327 keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1329 return keyarr, indexer
#
# File /usr/local/lib/python3.8/dist-packages/pandas/core/indexes/base.py:5782, in Index._get_indexer_strict(self, key, axis_name)
#    5779 else:
#    5780     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5782 self._raise_if_missing(keyarr, indexer, axis_name)
#    5784 keyarr = self.take(indexer)
#    5785 if isinstance(key, Index):
#    5786     # GH 42790 - Preserve name from an Index
#
# File /usr/local/lib/python3.8/dist-packages/pandas/core/indexes/base.py:5845, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5842     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5844 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 5845 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['taster_name', 'taster_twitter_handle'] not in index"

# %%
wineMag.set_index("title")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [42], in <cell line: 1>()
# ----> 1 wineMag.set_index("title")
#
# File /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:5494, in DataFrame.set_index(self, keys, drop, append, inplace, verify_integrity)
#    5491                 missing.append(col)
#    5493 if missing:
# -> 5494     raise KeyError(f"None of {missing} are in the columns")
#    5496 if inplace:
#    5497     frame = self
#
# KeyError: "None of ['title'] are in the columns"

# %%
wineMag.country=='Italy'
# Out:
# 0         False
# 1         False
# ```       False
# 150928    False
# 150929     True
# Name: country, dtype: bool

# %%
wineMag.loc[wineMag.country=='Italy']
# Out:
#        country  ...         winery
# 150929   Italy  ...  Alois Lageder
#
# [1 rows x 10 columns]

# %%
wineMag.loc[(wineMag.country=='Italy') & (wineMag.points>=90)]
# Out:
#        country  ...         winery
# 150929   Italy  ...  Alois Lageder
#
# [1 rows x 10 columns]

# %%
wineMag.loc[(wineMag.country=='Italy')|(wineMag.points>=90)]
# Out:
#        country  ...                   winery
# 0           US  ...                    Heitz
# 1        Spain  ...  Bodega Carmen Rodríguez
# 150928  France  ...                   Gosset
# 150929   Italy  ...            Alois Lageder
#
# [4 rows x 10 columns]

# %%
wineMag.loc[wineMag.country.isin(['Italy','France'])]
# Out:
#        country  ...         winery
# 150928  France  ...         Gosset
# 150929   Italy  ...  Alois Lageder
#
# [2 rows x 10 columns]

# %%
wineMag.loc[wineMag.price.notnull()]
# Out:
#        country  ...                   winery
# 0           US  ...                    Heitz
# 1        Spain  ...  Bodega Carmen Rodríguez
# 150928  France  ...                   Gosset
# 150929   Italy  ...            Alois Lageder
#
# [4 rows x 10 columns]

# %%
wineMag['critic']='everyone'

# %%
wineMag['critic']
# Out:
# 0         everyone
# 1         everyone
# ```       everyone
# 150928    everyone
# 150929    everyone
# Name: critic, dtype: object

# %%
wineMag['index_backwards'] = range(len(wineMag),0,-1)
wineMag['index_backwards']
# Out:
# 0         5
# 1         4
# ```       3
# 150928    2
# 150929    1
# Name: index_backwards, dtype: int64
